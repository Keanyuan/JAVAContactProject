# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1,3,4,5])

# %%
plt.plot([1,3,4,5], [1,4,5,6])

# %%
import numpy as np

# %%
# 三角函数
x = np.linspace(-np.pi, np.pi, 100)
y = np.cos(x)
plt.plot(x,y)
